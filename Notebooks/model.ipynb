# %% [markdown]
# In this notebook, we use the processed data from the `analysis.ipynb` file and applied the various methods on it to find the better r2_score. Saved the final model in pickle format for the prediction and at last done the prediction.

# %% [markdown]
# ### Importing files/data from analysis.ipynb file for creating model

# %%
import pprint
import nltk
import pandas as pd
import pickle
import requests
import numpy as np
import joblib
import import_ipynb

nltk.download('punkt')
pd.set_option('display.max_rows', None)
# %run analysis.ipynb import data, store_tag
# Out:
# [nltk_data] Downloading package punkt to /home/myth/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1500 entries, 0 to 1499
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   repo_name       1500 non-null   object
#  1   star            1500 non-null   object
#  2   fork            1500 non-null   object
#  3   watch           1500 non-null   object
#  4   issue           1500 non-null   object
#  5   tags            1500 non-null   object
#  6   description     1480 non-null   object
#  7   contributers    1500 non-null   object
#  8   license         1500 non-null   object
#  9   repo_url        1500 non-null   object
#  10  most_used_lang  1297 non-null   object
# dtypes: object(11)
# memory usage: 140.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2769 entries, 0 to 2768
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   repo_name       2769 non-null   object
#  1   star            2769 non-null   object
#  2   fork            2769 non-null   object
#  3   watch           2769 non-null   object
#  4   issue           2769 non-null   object
#  5   tags            2769 non-null   object
#  6   description     2590 non-null   object
#  7   contributers    2769 non-null   object
#  8   license         2174 non-null   object
#  9   repo_url        2769 non-null   object
#  10  most_used_lang  2769 non-null   object
# dtypes: object(11)
# memory usage: 238.1+ KB
#         most_used_lang                                           repo_url  \
# 202                C++  https://github.com/oreillymedia/Learning-OpenC...
# 214             Python  https://github.com/MicrocontrollersAndMore/Ope...
# 219               Java                   https://github.com/xikuqi/OpenCV
# 234                C++  https://github.com/MicrocontrollersAndMore/Ope...
# 242                C++         https://github.com/saki4510t/OpenCVwithUVC
# 245             Python  https://github.com/MicrocontrollersAndMore/Ras...
# 253             Python  https://github.com/MicrocontrollersAndMore/Ope...
# 269                C++  https://github.com/MicrocontrollersAndMore/Ope...
# 291                C++  https://github.com/MicrocontrollersAndMore/Ope...
# 356                CSS  https://github.com/handong1587/handong1587.git...
# 428             Python   https://github.com/martinarjovsky/WassersteinGAN
# 449             Python            https://github.com/hanzhanggit/StackGAN
# 482             Python                https://github.com/taoxugit/AttnGAN
# 495         JavaScript        https://github.com/lypeer/wechat-weapp-gank
# 498             Python  https://github.com/brain-research/self-attenti...
# 654         FreeMarker  https://github.com/vsay01/Android-Studio-MVP-T...
# 677        no language           https://github.com/quanke/android-studio
# 780               Dart            https://github.com/YYFlutter/flutter-ui
# 1182       Objective-C   https://github.com/TKkk-iOSer/WeChatPlugin-MacOS
# 1344               C++      https://github.com/br3ttb/Arduino-PID-Library
# 1500               CSS  https://github.com/mojombo/30daysoflaptops.git...
# 1509       no language  https://github.com/mojombo/conceptual_algorith...
# 1511        TypeScript        https://github.com/mojombo/docz-website.git
# 1516       no language  https://github.com/mojombo/erlectricity-presen...
# 1530              Ruby   https://github.com/wycats/abbot-from-scratch.git
# 1533       no language        https://github.com/wycats/active_params.git
# 1536              Ruby   https://github.com/wycats/allocation_counter.git
# 1537              Rust                https://github.com/wycats/argon.git
# 1538       no language        https://github.com/wycats/argon-example.git
# 1546              Ruby    https://github.com/wycats/bootstrap-nitrous.git
# 1548        TypeScript  https://github.com/wycats/broccoli-typescript-...
# 1549              Ruby              https://github.com/wycats/bundler.git
# 1552               CSS        https://github.com/wycats/cargo-website.git
# 1553              Rust               https://github.com/wycats/chacha.git
# 1554              Ruby    https://github.com/wycats/chainable_compare.git
# 1559        TypeScript         https://github.com/wycats/core-storage.git
# 1571              Ruby    https://github.com/rubinius/ffi2-generators.git
# 1625              Ruby    https://github.com/defunkt/barefootexamples.git
# 1635       Objective-C  https://github.com/defunkt/currency_converter.git
# 1642       no language   https://github.com/defunkt/electron-wordwrap.git
# 1644              Ruby  https://github.com/defunkt/email_reply_parser.git
# 1651       no language             https://github.com/technoweenie/15.git
# 1652              Ruby  https://github.com/technoweenie/activesupport_...
# 1664                Go        https://github.com/technoweenie/camo.go.git
# 1668      CoffeeScript  https://github.com/technoweenie/coffee-resque.git
# 1672                Go     https://github.com/technoweenie/dangerroom.git
# 1673        JavaScript      https://github.com/technoweenie/dealer.js.git
# 1674       no language     https://github.com/technoweenie/dummy-repo.git
# 1677            Elixir  https://github.com/technoweenie/elixir-rubypor...
# 1683        JavaScript             https://github.com/caged/attractor.git
# 1684             Shell             https://github.com/caged/bash-test.git
# 1685  Jupyter Notebook      https://github.com/caged/basketball-stats.git
# 1690        JavaScript               https://github.com/caged/cartile.git
# 1692              Ruby        https://github.com/caged/cfb-recruiting.git
# 1693              HTML              https://github.com/caged/choochoo.git
# 1695             Shell              https://github.com/caged/city-gen.git
# 1696            Python              https://github.com/caged/citylist.git
# 1702          Makefile          https://github.com/caged/construction.git
# 1713        JavaScript           https://github.com/anotherjesse/barb.git
# 1721            Python      https://github.com/anotherjesse/cloudenvy.git
# 1725        Emacs Lisp       https://github.com/anotherjesse/dotfiles.git
# 1734        JavaScript        https://github.com/anotherjesse/finally.git
# 1741              Ruby   https://github.com/macournoyer/cache_digests.git
# 1747              Ruby      https://github.com/macournoyer/gh-contest.git
# 1772              Ruby  https://github.com/jamesgolick/activerecordles...
# 1792              Ruby  https://github.com/jamesgolick/dirty_callbacks...
# 1794              VimL        https://github.com/jamesgolick/dotfiles.git
# 1795              Ruby      https://github.com/jamesgolick/enum_field.git
# 1798            Erlang   https://github.com/jamesgolick/erlang-thrift.git
# 1801        JavaScript          https://github.com/KirinDave/atm6-sky.git
# 1819              Java  https://github.com/KirinDave/Equivalent-Exchan...
# 1824       no language          https://github.com/KirinDave/fake-tpw.git
# 1835                Go            https://github.com/bmizerany/aws.go.git
# 1846                Go            https://github.com/bmizerany/coreup.git
# 1849                Go      https://github.com/bmizerany/describe-tag.git
# 1858                Go               https://github.com/bmizerany/env.git
# 1861        Dockerfile  https://github.com/jnewland/action-kots-releas...
# 1862       no language  https://github.com/jnewland/actions-playground...
# 1864              Ruby          https://github.com/jnewland/agile_zen.git
# 1888       no language           https://github.com/jnewland/dotfiles.git
# 1920             Shell                 https://github.com/uggedal/cfg.git
# 1966           Clojure  https://github.com/mmower/expectations-test-ca...
# 1973       no language       https://github.com/abhay/abhay.github.io.git
# 1996       no language           https://github.com/abhay/minesweeper.git
# 2007                Go        https://github.com/benburkert/cheeseman.git
# 2009              Ruby        https://github.com/benburkert/chef_fail.git
# 2019             Shell  https://github.com/benburkert/docker-fluentd-l...
# 2031       no language         https://github.com/benburkert/ey-check.git
# 2038             Shell         https://github.com/sr/ansible-role-cbk.git
# 2040              Ruby            https://github.com/sr/aperorb-paris.git
# 2048              Ruby                  https://github.com/sr/bundler.git
# 2066        JavaScript   https://github.com/queso/anywherejs-template.git
# 2067              Ruby         https://github.com/queso/autoserialize.git
# 2070              HTML            https://github.com/queso/boozio-web.git
# 2074               CSS    https://github.com/queso/crater-remote-conf.git
# 2093             Shell             https://github.com/drnic/.dotfiles.git
# 2097                Go  https://github.com/drnic/alexa-skill-dice-roll...
# 2100                Go         https://github.com/drnic/apt-buildpack.git
# 2102             Shell          https://github.com/drnic/ardupilot-ci.git
# 2111       no language     https://github.com/drnic/Backbone.tmbundle.git
# 2113       no language         https://github.com/drnic/Bats.tmbundle.git
# 2121        TypeScript      https://github.com/drnic/bom-charts-lsalt.git
# 2122              Ruby   https://github.com/drnic/bootstrap-cf-plugin.git
# 2131              Ruby   https://github.com/danwrong/google-analytics.git
# 2169       no language  https://github.com/wayneeseguin/concourse-proj...
# 2172       no language  https://github.com/wayneeseguin/data_retention...
# 2174       no language            https://github.com/wayneeseguin/dbm.git
# 2198              Ruby         https://github.com/mattetti/benchmarks.git
# 2208       Objective-C        https://github.com/mattetti/bugsnag-ios.git
# 2217        JavaScript  https://github.com/grempe/diceware-wordlist-en...
# 2228        JavaScript              https://github.com/grempe/pem-jwk.git
# 2229       no language     https://github.com/grempe/qldb-simple-demo.git
# 2245              Ruby               https://github.com/peterc/author.git
# 2261       no language             https://github.com/peterc/iA-Fonts.git
# 2270              Ruby          https://github.com/peterc/netlifytest.git
# 2276            Erlang    https://github.com/hornbeck/Little-Erlanger.git
# 2279       no language               https://github.com/hornbeck/test.git
# 2282              Ruby  https://github.com/up_the_irons/arpnet-toolbox...
# 2283       no language  https://github.com/up_the_irons/arpnetworks-pa...
# 2290        Vim script       https://github.com/up_the_irons/dotfiles.git
# 2293             Shell     https://github.com/up_the_irons/git-winner.git
# 2294              Ruby           https://github.com/up_the_irons/gogo.git
# 2301        JavaScript  https://github.com/up_the_irons/mobile-experim...
# 2314               CSS  https://github.com/atmos/atmos-dot-org-netlify...
# 2316              HTML       https://github.com/atmos/atmos.github.io.git
# 2320               Lua  https://github.com/atmos/brute-force-your-rout...
# 2323              Ruby          https://github.com/atmos/bundler-site.git
# 2338       no language  https://github.com/atmos/docker-unifi-controll...
# 2340              Ruby  https://github.com/atmos/elasticsearch-client.git
# 2341        Dockerfile  https://github.com/brosner/airship-container-i...
# 2343             Shell             https://github.com/brosner/apk-rkt.git
# 2351       no language  https://github.com/brosner/brosner.github.com.git
# 2355       no language         https://github.com/brosner/colour_qwiz.git
# 2363            Python   https://github.com/brosner/django-basic-cart.git
# 2381        JavaScript      https://github.com/jnicklas/broccoli-sass.git
# 2426               HCL  https://github.com/simonjefford/atlas-terrafor...
# 2439        Emacs Lisp        https://github.com/simonjefford/emacs.d.git
# 2441        Emacs Lisp  https://github.com/simonjefford/emacsconfig-ol...
# 2442        JavaScript      https://github.com/simonjefford/ember-cli.git
# 2444        JavaScript  https://github.com/simonjefford/ember-github-i...
# 2447                Go      https://github.com/simonjefford/fourthbot.git
# 2448       no language         https://github.com/simonjefford/gftest.git
# 2450       no language       https://github.com/simonjefford/git-talk.git
# 2456             Shell       https://github.com/leahneukirchen/absurd.git
# 2467       no language  https://github.com/leahneukirchen/atreus-leah2...
# 2514              Ruby  https://github.com/engineyard/datafabric-examp...
# 2515              Rust  https://github.com/kevinclark/AdventOfCode2020...
# 2533            Python     https://github.com/kevinclark/Lesson-Plans.git
# 2563        Emacs Lisp  https://github.com/technomancy/commodore-night...
# 2582              HTML     https://github.com/sevenwire/gotogether.co.git
# 2586              Ruby  https://github.com/sevenwire/sevenwire-rubocop...
# 2587              HTML     https://github.com/sevenwire/sevenwire.com.git
# 2589              Ruby  https://github.com/technicalpickles/4tehlulz.b...
# 2623               CSS     https://github.com/lazyatom/aemeredith.com.git
# 2626              HTML    https://github.com/lazyatom/cmmid.github.io.git
# 2646             Shell  https://github.com/lazyatom/heroku-buildpack-a...
# 2649             Swift                  https://github.com/josh/Aware.git
# 2651        Dockerfile        https://github.com/josh/certbot-tickerd.git
# 2656             Shell               https://github.com/josh/dotfiles.git
# 2658        Dockerfile    https://github.com/josh/google-domains-ddns.git
# 2659                Go        https://github.com/josh/hktwiliocallbox.git
# 2665       no language                   https://github.com/josh/josh.git
# 2666        JavaScript    https://github.com/josh/jquery-selector-set.git
# 2670        Dockerfile      https://github.com/josh/offlineimap-gmail.git
# 2681        JavaScript         https://github.com/cdcarter/bitstarter.git
# 2683       no language  https://github.com/cdcarter/bootstrap-visualfo...
# 2684              HTML  https://github.com/cdcarter/cdcarter.github.co...
# 2691              Apex       https://github.com/cdcarter/crowdbuilder.git
# 2709       no language        https://github.com/bs/2021-usa-roadtrip.git
# 2715  Jupyter Notebook   https://github.com/bs/cocktail-party-problem.git
# 2720       no language         https://github.com/bs/from_zero_to_DSP.git
# 2722       no language     https://github.com/bs/hello-github-actions.git
# 2725        JavaScript              https://github.com/bs/jschesstest.git
# 2727       no language       https://github.com/bs/markdown-portfolio.git
# 2729       no language           https://github.com/bs/oss-enterprise.git
# 2734            Groovy        https://github.com/bs/SmartThingsPublic.git
# 2758              Ruby       https://github.com/collectiveidea/bender.git
# 2759             Swift    https://github.com/collectiveidea/BTExample.git
# 2763              Ruby  https://github.com/collectiveidea/calendar_bui...
#
#        star
# 202    1.4k
# 214     405
# 219     317
# 234     217
# 242     154
# 245     143
# 253     128
# 269     105
# 291      74
# 356      3k
# 428    2.6k
# 449    1.6k
# 482     911
# 495     749
# 498     718
# 654     111
# 677      92
# 780    1.2k
# 1182  13.5k
# 1344   1.1k
# 1500      7
# 1509      4
# 1511      1
# 1516      4
# 1530      8
# 1533      7
# 1536      7
# 1537     12
# 1538      1
# 1546      2
# 1548      0
# 1549    412
# 1552      5
# 1553      1
# 1554     11
# 1559      4
# 1571      1
# 1625      6
# 1635      8
# 1642      5
# 1644      7
# 1651      3
# 1652     10
# 1664      4
# 1668    546
# 1672      7
# 1673     21
# 1674      1
# 1677      4
# 1683      1
# 1684      1
# 1685      1
# 1690      1
# 1692      1
# 1693      0
# 1695      0
# 1696      1
# 1702      1
# 1713      1
# 1721      1
# 1725      3
# 1734      6
# 1741      1
# 1747      2
# 1772      2
# 1792      6
# 1794     17
# 1795     53
# 1798      1
# 1801      0
# 1819      1
# 1824      3
# 1835      2
# 1846      0
# 1849      0
# 1858      0
# 1861      0
# 1862      1
# 1864      5
# 1888      0
# 1920      4
# 1966      0
# 1973      0
# 1996      0
# 2007      1
# 2009      1
# 2019      0
# 2031      1
# 2038      0
# 2040      2
# 2048      2
# 2066      0
# 2067      0
# 2070      0
# 2074      0
# 2093     11
# 2097      0
# 2100      0
# 2102      0
# 2111     20
# 2113     10
# 2121      0
# 2122      0
# 2131      7
# 2169      1
# 2172      1
# 2174      2
# 2198      7
# 2208      0
# 2217      1
# 2228      0
# 2229      0
# 2245      0
# 2261      0
# 2270      0
# 2276      8
# 2279      0
# 2282      1
# 2283      0
# 2290      3
# 2293      4
# 2294      0
# 2301      0
# 2314      1
# 2316     32
# 2320      5
# 2323      2
# 2338      0
# 2340      2
# 2341      0
# 2343      0
# 2351      1
# 2355      0
# 2363      6
# 2381      0
# 2426      0
# 2439      0
# 2441      2
# 2442      0
# 2444      0
# 2447      0
# 2448      0
# 2450      0
# 2456      0
# 2467      1
# 2514      2
# 2515      1
# 2533     16
# 2563      2
# 2582      0
# 2586      0
# 2587      0
# 2589      1
# 2623      0
# 2626      0
# 2646      0
# 2649    139
# 2651      0
# 2656     60
# 2658      4
# 2659      0
# 2665      1
# 2666    219
# 2670      2
# 2681      0
# 2683      0
# 2684      1
# 2691      0
# 2709      0
# 2715      0
# 2720      0
# 2722      0
# 2725      0
# 2727      0
# 2729      0
# 2734      0
# 2758      8
# 2759      0
# 2763     42
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2769 entries, 0 to 2768
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   repo_name       2769 non-null   object
#  1   star            2769 non-null   object
#  2   fork            2769 non-null   object
#  3   watch           2769 non-null   object
#  4   issue           2769 non-null   object
#  5   tags            2769 non-null   object
#  6   description     2769 non-null   object
#  7   contributers    2769 non-null   object
#  8   license         2174 non-null   object
#  9   repo_url        2769 non-null   object
#  10  most_used_lang  2769 non-null   object
# dtypes: object(11)
# memory usage: 238.1+ KB
# applications
# awesome-list
# opensource
# open-source
# awesome
# swift
# objective-c
# javascript
# python
# ruby
# c
# c-plus-plus
# macos-application
#
#
# chat
# meteor
# javascript
# collaboration
# webrtc
# real-time
# slack
# foss
# free
# mit
#
#
# carbon
# javascript
# beautiful
# snippets
# github-gist
# sharing
# education
# tweet
# presentation
# angular
# cli
# angular-cli
# typescript
# codehub
# c-sharp
# github
# reactiveui
# php
# composer
# dependency-manager
# package-manager
# packages
# swift
# data-structures
# algorithms
#
# javascript
# screenshot
# dom
# itchat
# wechat
# api
# robot
# imgui
# gui
# gamedev
# tools
# ui
# toolkit
# native
#
# command-line-tool
# c
# silver-searcher
# pcre
# ag
# search-in-text
# vim
# c
# text-editor
# cross-platform
# reactiveswift
# reactivecocoa
# swift
# uwp
# windows
# windows-10
# xaml
# cpp
# csharp
# angular
# material-design
# material
# angular-components
# test
# testing
# testing-tools
# test-suite
# test-automation
# test-runner
# tests
# javascript-tests
# cypress
# end-to-end-testing
# e2e-testing
# e2e-tests
# python
# algorithm
# data-structure
# development
# programming
# coding
# interview
# interview-questions
# interview-practice
# competitive-programming
#
# ffmpeg
# video
# audio
# c
# mpeg
# webm
# mp4
# matroska
# hls
# rtsp
# rtmp
# hevc
# fft
# multimedia
# streaming
#
# gbdt
# gbrt
# gbm
# distributed-systems
# xgboost
# machine-learning
#
# c
# c-plus-plus
# live-streaming
# video-recording
# screen-capture
# game-capture
# directshow
# ffmpeg
# twitch-tv
# facebook-live
# youtube-live
# cheatsheet
# curl
# terminal
# command-line
# cli
# examples
# documentation
# help
# tldr
# json
# json-pointer
# json-patch
# cbor
# msgpack
# header-only
# stl-containers
# json-serialization
# json-parser
# rfc-6901
# rfc-6902
# rfc-7159
# rfc-7049
# json-diff
# messagepack
# rfc-8259
# ubjson
# json-merge-patch
# bson
# docker
# cheet-sheet
# go
# database
# sql
# distributed-database
# cockroachdb
# php
# corefx
# coreclr
# microsoft
# csharp
# dotnet
# dotnet-core
# dotnetcore
#
# homebrew
# cask
#
#
# cognitive-toolkit
# cntk
# deep-learning
# machine-learning
# deep-neural-networks
# neural-network
# distributed
# python
# c-plus-plus
# c-sharp
# java
# deep-learning
# pytorch
# tensorflow
# tts
# voice-cloning
# python
#
#
#
#
#
#
#
#
# gank
# rxjava
# material
# gityuan
# notebook
# meizi
#
# procedural-generation
# machine-learning
# gamedev
# algorithm
# csharp
# wfc
# ios
# database
# swift
# objective-c
# sync
# mobile-database
# threadsafe
# realtime
# mobile
# docker
# netcore
# windowscontainers
# xamarin
# spa
# microservices
# ddd
# ddd-patterns
# cocoa
# carthage
# swift
# package-manager
#
#
# macos
# wechat
# weixin
# tweak
# plugin
# alfred-workflow
# dotnet
# dotnet-core
#
# serverless
# integration-testing
# headless-chrome
# headless
# graphcool
# nightmarejs
# selenium
# chrome
# proposal
# polyfill
# shim
# es6
# promise
# weakmap
# es7
# es2015
# esnext
# symbol
# ponyfill
# es2019
# javascript
# js
# keras
# deep-learning
# seq2seq
# encoder-decoder
# lstm
# floydhub
# machine-learning
# cnn
# cnn-keras
# jupyter-notebook
# jupyter
# cheatsheet
# python
# python-3
# owasp
# code
# security
# cheatsheets
# best-practices
# appsec
# retro
# qml
# qt
# macos
# linux
# terminal
# radare2
# c
# commandline
# reverse-engineering
# forensics
# security
# binary-analysis
# malware-analysis
# disassembler
# polyglot
# vm
# java
# javascript
# python
# r
# ruby
# c
#
# frontend
# front-end-development
# front-end-developer-tool
# guidelines
# checklist
# reference
# web-development
# html
# css
# javascript
# lists
# resources
# performance
# performance-metrics
# linux
# linux-command
# search
# screen
# screenshot
# ls
# ssh
# bash
# gh-pages
# command-line
# chrome
#
# polyglot
# vm
# java
# javascript
# python
# r
# ruby
# c
# cheatsheets
# javascript
# bash
# nodejs
# cheatsheet
# database
# language
# frontend
# backend
# feathersjs
# redis
# vuejs
# vim
# django
# programming-language
# xcode
# php
# docker
# kubernetes
# sailsjs
# linux
# linux-command
# search
# screen
# screenshot
# ls
# ssh
# bash
# gh-pages
# command-line
# chrome
# raspberry-pi
# pi
# retrogaming
# emulation
# raspberry-pi
# linux-kernel
# osdev
# arm
# operating-system
# raspberry-pi-3
# armv8
# kernel
# tutorial
# c
# assembler
# education
# resource
# raspberry-pi-os
# learn
# go
# gui-framework
# qt
# cross-platform-gui
# windows
# macos
# linux
# android
# ios
# sailfish-os
# raspberry-pi
# asteroidos
# ubuntu-touch
# golang
# javascript
# webassembly
# felgo
# freebsd
# awesome
# raspberry-pi
# resources
# list
# awesome-list
#
#
#
# nodejs
# raspberry
# phone
# javascript
# home-automation
# react-native
#
# openvpn
# openvpn-installer
# pivpn
# raspberry-pi
# wireguard
# vpn-server
#
# arduino
# esp8266
# esp32
# particle-photon
# embedded
# hardware
# mbed
# raspberry-pi
# bluetooth
# bluetooth-low-energy
# serialport
# ethernet-shield
# gsm
# ota
# iot
# internet-of-things
# espressif
# iot-platform
# wifi
#
# spotify
# librespot
# spotify-connect
# raspberry-pi
# raspbian
#
# raspberry-pi
# tensorflow
# machine-learning
#
# java
# iot
# netty
# blynk-server
# internet-of-things
# arduino
# raspberry-pi
# mqtt
# esp8266
# iot-platform
# http
# websockets
# home-automation
# ota
# blynk
# esp32
# particle-photon
# rest-api
# ssl-certificate
# hardware
# raspberry-pi
# rgb-panels
# led-panels
# multiplexing
# gpio
#
#
#
#
# raspberry-pi
# music-visualizer
# python
# esp8266
# arduino
# signal-processing
# audio-processing
# rf24
# arduino-library
# c-plus-plus
# nrf24l01
# arduino
# sonos
# raspberry-pi
# deep-learning
# tensorflow
# iot
# mqtt
# aiot
# edge-devices
# edge-ai
# openvino
# tensorrt
#
# raspberry-pi
#
# raspberry-pi
# deep-learning
# tensorflow
# iot
# mqtt
# aiot
# edge-devices
# edge-ai
# openvino
# tensorrt
#
# raspberry-pi
#
# raspberry-pi
# crankshaft
# rpi
# rpi3
# raspberrypi
# distro
# raspbian
# raspbian-lite
# android-auto
# phone
# openauto
# aasdk
#
#
#
#
#
# raspberry-pi
# raspberry-pi-camera
# python
# mraa
# libmraa
# intel-joule
# board
# raspberry-pi
# communication
# galileo
# io
# linux
# i2c
# gpio
# spi
#
#
# pi
# raspberry
# raspberry-pi-3
# arm64
# arm64v8
# armv8
# aarch64
# pi-64
# pi64
# raspberrypi
# raspberry-pi
# raspberry-pi-3b
# raspberry-pi-3b-plus
# pi-4b
# deepin
# raspberry-pi-4
# pi4
# rpi-4b
# raspberry-pi-4b
# pi-64bit
# nextcloud
# qemu
# docker-image
# raspbian
# raspberry-pi
# arm
# x86-64
# gpio
# raspberry-pi
# python
# education
# zero-boilerplate
#
#
#
# dramble
# raspberry-pi
# bramble
# cluster
# ansible
# automation
# devops
# drupal
# distributed
# kubernetes
# docker
#
# vpn
# raspberry-pi
# linux
# strongswan
# homebridge
# docker
# raspberry-pi
# x86-64
# homekit
# siri
# alpine-linux
# armhf
# homebridge-docker
# docker-homebridge
# rpi
# armv6
# arm
# arm64
# aarch64
# arm6
# ffmpeg
# libfdk-aac
#
# docker
# raspberry-pi
# docker-compose-commands
# grafana
# influxdb
# portainer
# mosquitto
# postgres
# nodered
# mqtt
# sd-card-image
# raspberry-pi
# image-builder-rpi
# vagrant
# docker-machine
# hypriot-os
# docker
#
# docker
# docker-image
# raspberry-pi
# virtual-machine
# qemu
# vm
# arm
# container
#
#
#
#
#
#
# bitcoin
# lightning
# cryptocurrency
# raspberry-pi
# uefi
# 64-bit
# rpi3
# raspberry-pi-3
# raspberry-pi-uefi
# windows-10
# windows-on-arm
# armv8
# aarch64
# arm64
# arm
# firmware
# rpi
# freebsd
# arm-linux
# ubuntu-arm
# opensuse
# win10
# raspberrypi
#
# raspberry-pi
# kiosk-mode
# dashboard
#
# raspberry-pi
# tensorflow
# self-driving-car
# dfn
# cnn
# nxt-python
#
# farmbot
# nerves
# elixir
# kubernetes
# kubernetes-cluster
# k8s
# devops
# cka
# ckad
# serverless
# faas
# cloud
# bare-metal
# raspberry-pi
# linux-distribution
# debian
# raspberry-pi-3
# linux-kernel
# 64-bit
# linux
# os
# raspberrypi
#
# raspberry-pi
# windows
# windows-on-arm
# arm
# aarch64
# deployer
#
#
#
#
#
#
# tensorflow
# raspberry-pi
# self-driving-car
# sitewhere
# internet-of-things
# integration
# device-management
# iot
# iot-platform
# platform
# mqtt
# iot-framework
# java
# arduino
# raspberry-pi
# android
# open-source
# aws
# kafka
# zookeeper
# microservices
# kubernetes
# helm
#
# raspberry-pi
# raspbian
# wifi-hotspot
# instructions
# chromium-os
# chrome-os
# raspberry-pi
# raspberry-pi-3
# chromium
# operating-system
# linux-distribution
# linux
# boot-raspberry-pi
# overlay
# raspberry-pi-3b
# disk-image
# chromeos
# chromiumos
# fydeos
# flintos
# flint-os
# gpio
# pwm
# servo
# motor
# interrupt
# hc-sr04
# raspberry-pi
# javascript
# nodejs
# iot
# raspberry-pi
# android
# chrome-extension
# cast-videos
# firefox-extension
# youtube
# video
# vimeo
# raspberry-pi
# wireguard
# vpn
#
# freeswitch
# signalwire
# open-source
# source-code
# voip
# webrtc
# telephony
# sip
# iot
#
#
#
# raspberry-pi
# raspberry-pi-3
# raspbian
# rpi
# rpi3
# picroft
# mycroft
# personal-assistant
# machine-learning
# opensource
# open-source
# artificial-intelligence
# home-automation
# smarthome
# pimatic
# nodejs
# balena
# balenacloud
# raspberry-pi
# raspberrypi
# bluetooth-audio
# bluetooth
# airplay
# spotify-connect
# audio
# bluetooth-devices
# multi-room
# snapcast
# ipmi
# raspberrypi
# raspberry-pi
# javascript
# arduino
# tessel
# raspberry-pi
# chip
# photon
# pcduino
# gpio
# i2c
# adc
# dac
# pwm
# spi
# serial
# 1-wire
# bluetooth
# iot
# robotics
# beaglebone-black
# intel
#
# tasmota
# firmware
# esp8266
# sonoff
# tuya
# knx
# arduino
# iot
# mqtt
# ota
# automation
# smart-home
#
# reprap
# arduino
# 3d-printing
# firmware
# avr
# atmel
# stmicro
# esp32
# wifi
# arduino
# attack
# esp8266
# deauth
# hack
# deauther
# board
# scanning
# robotics
# iot
# drone
# go
# robot
# uav
# arduino
# raspberry-pi
# beaglebone
# beaglebone-black
# intel-joule
# sphero
# bluetooth
# gpio
# i2c
# internet-of-things
# intel-edison
# hardware
# mqtt
# bluetooth-le
# linux-kernel-hacking
# c-programming
# hardware
# embedded-systems
# programming-language
# low-level-programming
# assembly-language-programming
# linux-kernel
# low-level
# assembly
# arduino
# system-programming
# firmware
# golang
# microcontroller
# tinygo
# llvm
# wasm
# webassembly
# arduino
# arm
# microbit
# samd21
# stm32
# nrf51
# nrf52
# nrf52840
# circuitplayground-express
# avr
# i2c
# spi
# gpio
# adafruit
# arduino
# esp-idf
# platformio
# esp32
# arduino
# c-plus-plus
# iot
# embedded
# arduino-library
# json
# esp8266
# iot
# embedded
# arduino
# mbed
# esp8266
# esp32
# fpga
# firmware
# avr
# arm
# platformio
# ide
# unit-testing
# hardware
# verilog
# python
# microcontroller
# debug
# risc-v
# esp8266
# configuration-portal
# wifimanager
# arduino
# captive
#
# javascript
# arduino
# beaglebone-black
# raspberry-pi
# gpio
# i2c
# sphero
# chip
# iot
# internet-of-things
# intel-joule
# intel-edison
# bluetooth-low-energy
# robotics
# drones
#
#
#
# arduino
# esp8266
# esp32
# particle-photon
# embedded
# hardware
# mbed
# raspberry-pi
# bluetooth
# bluetooth-low-energy
# serialport
# ethernet-shield
# gsm
# ota
# iot
# internet-of-things
# espressif
# iot-platform
# wifi
#
#
# arduino
# cli
# command-line
# bash
# golang
# builder
# arduino-tool
# cmake
#
# wasm
# interpreter
# webassembly
# embedded
# esp32
# esp8266
# risc-v
# arm
# arduino
# blockchain
# iot
# scripting
# edge-computing
# iot
# open-source
# arduino
# attiny85
# esp8266
# teensy
# raspberry-pi
# windows
# network
# hc-12
# internet-of-things
# linux
# decentralization
# privacy
# cpp
# protocol
# communication
# mqtt
# tcp
# udp
#
# mqtt
# serial
# esp-8266
# esp8266
# esp8266mqtt
# serial-bridge
#
# java
# iot
# netty
# blynk-server
# internet-of-things
# arduino
# raspberry-pi
# mqtt
# esp8266
# iot-platform
# http
# websockets
# home-automation
# ota
# blynk
# esp32
# particle-photon
# rest-api
# ssl-certificate
# hardware
#
#
# mqtt
# gateway
# openhab2
# home-automation
# home-assistant
# wemos-d1
# rcswitch
# arduino
# bridge
# nodemcu
# ble-beacons
# esp8266
# arduino-uno
# miflora
# esp32
# xiaomi
# ble
#
# raspberry-pi
# music-visualizer
# python
# esp8266
# arduino
# signal-processing
# audio-processing
# rf24
# arduino-library
# c-plus-plus
# nrf24l01
# arduino
# js
# arduino
# raspberry
# compilation
# nodejs
# wasm
#
#
#
#
# arduino
# nodejs
# browser
# html5
# websocket
# serial
#
# i2c
# spi
# arduino
# driver
# ssd1306
# esp8266
# esp32
# sh1106
# mbed-os
# oleddisplay
# esp8266
# espressif
# iot
# iot-framework
# wifi
# embedded
# sming
# ssl-support
# arduino
# microcontroller
# async
# rboot
# c-plus-plus
# internet-of-things
#
# mqtt
# homie
# iot
# esp8266
# arduino
# framework
# home-automation
#
#
# mysensors
# iot
# home-automation
# arduino
# samd
# esp8266
# raspberry
# diy
# stm32f103
# nrf5x
# esp32
# teensyduino
#
# arduino-library
# websocket-server
# wss
# ws
# websocket
# websockets
# websocket-client
# esp8266
# esp
#
#
#
#
#
# particle
# photon
# electron
# core
# arduino
# c
# c-plus-plus
# iot
# p1
# argon
# boron
# xenon
#
# gprs
# lte
# arduino
# blynk
# mqtt
# neoway
# quectel
# m590
# sim800
# sim900
# a6
# a7
# rest-api
# ublox
# sim7000
# modem
# esp32
# esp8266
# xbee
#
# ws2812
# led
# esp8266
# arduino
# arduino-library
# neopixel
# adafruit-neopixel-library
# arduino
# atmega32u4
# esp8266
# ducky
# keytroke
# injection
# hack
# script
# arduino
# stm32f0
# stm32f1
# stm32f2
# stm32f3
# stm32f4
# stm32f7
# stm32l0
# stm32l1
# stm32l4
# nucleo32
# nucleo64
# nucleo144
# discovery
# stm32h7
# stm32g0
# stm32wb
# stm32g4
# stm32mp1
# stm32core
# enc28j60
# arduino
# ethernet
#
#
# clojure
# lisp
# compiler
# bare-metal
# microcontroller
# embedded-systems
# arduino
# teensy
# atmega
# arm
#
# arduino-midi-library
# midi
# arduino
# arduino-library
# tft
# arduino
# stm32
# esp32
# esp8266
# tft-displays
# mqtt
# home-assistant
# esp8266
# home-automation
# sonoff
# diy
# domotic
# esp32
# home-assistant-config
# arduino
# ble
# nfc
# attiny
# arduino
# avr
# microcontroller
# gamepad
# arduino-micro
# arduino-library
# joystick-library
# arduino-leonardo
#
#
#
# arduino
# esp8266
# esp32
# 3d-printer
# firmware
# repetier
# wifi
# esp8285
# marlin
# smoothieware
#
# neopixels
# arduino
# led-controlling
# led-strips
# rgb-led
# ws2812
# ws2812b
# sk6812
# ws2813
# esp8266-arduino
# esp32-arduino
# wire-protocol-rgb
# apa106
# apa102
# ws2811
# dotstar
# dotstar-leds
# lpd8806
# rgbw-leds
# nano-33-ble
# wifi
# arduino
# attack
# esp8266
# deauth
# hack
# probe
# beacon
# board
# material-design
# material-ui
# material-theme
#
# weather-station
# thingpulse
# esp8266
# openweathermap
# openweathermap-client
# openweathermap-api
# weather-information
# arduino
# arduino-library
# arduino
#
# mpu9250
# sensor-fusion
# arduino
# arduino-library
#
# arduino
# esp8266
# mod
# wav
# mp3
# dac
# i2s
# flac
# midi
# aac
# soundfont2
# sf2
# esp32
# rtttl
#
#
# arduino
# library
# sensor
#
# sitewhere
# internet-of-things
# integration
# device-management
# iot
# iot-platform
# platform
# mqtt
# iot-framework
# java
# arduino
# raspberry-pi
# android
# open-source
# aws
# kafka
# zookeeper
# microservices
# kubernetes
# helm
#
#
# wifi
# ttgo
# lopy
# heltec
# ttn
# lorawan
# lora
# thethingsnetwork
# esp32
# platformio
# macaddr
# sniffing
# hackster
# bme680
# gps
# gps-tracker
# gps-tracking
# pycom
# arduino
# dcf77
#
# arduino
# mqtt
# iot
# usb
# rubberducky
# penetration
# penetration-testing
# hacker
# hacking
# powershell-attack
# payload
# arduino
# badusb
# teensy
# arduino-library
# arduino
# unity
# hardware-libraries
# hardware
# threading
# threadsafe
# iot
# iot-framework
# tshark
# wifi
# location
# sensor
# machine-learning
# cnn
# deep-learning
# opencv
# computer-vision
# sensor
# device-sensors
# monitoring-service
# prototype-android-application
# android
# slam
# mapping
# localization
# robotics
# self-driving
# security
# malware
# intrusion-detection
# sensor
# heuristics
# python
# network-monitoring
# machine-learning
# deep-learning
# lstm
# human-activity-recognition
# neural-network
# rnn
# recurrent-neural-networks
# tensorflow
# activity-recognition
# android-library
# detect-gestures
# gesture-detection
# sensor
# shake-detection
# handwave-detection
# light-detection
# android
# movement-detection
# chop-detection
# wrist-twist-detection
# proximity-sensor
# wave-detection
# libraries
#
# android
# easydeviceinfo
# android-library
# mod
# device
# information
# annotations
# library
# details
# cpu
# battery
# bluetooth
# location
# nfc
# memory
# display
# identifier
# network
# telephony
# sensor
#
#
#
# mysensors
# iot
# home-automation
# arduino
# samd
# esp8266
# raspberry
# diy
# stm32f103
# nrf5x
# esp32
# teensyduino
#
#
# automation
# home-assistant
# hassio
# lovelace
# lovelace-ui
# custom
# graph
# sensor
#
# iot-device
# sensor
# edge-machine-learning
# resource-constrained-ml
# machine-learning-algorithms
# microsoft-research
# machine-learning
# tensorflow
# deep-learning
# edge-computing
# microsoft
# edge-devices
# classifier
# emi-rnn
# pytorch
# bonsai
# protonn
# fastgrnn
# cpp
# fastrnn
#
#
#
# pentesting
# hacking
# hacking-tool
# pentest-tool
# automation
# security
# security-tools
# infosec
# pentest
# red-team
# blue-team
# red-teams
# blue-teams
# pentest-tools
# hacking-tools
# mpu9250
# sensor-fusion
#
# lighthouse
# position-tracker
# htc-vive-lighthouse
# htc-vive
# 3d
# positioning
# arduino
# library
# sensor
#
# actuators
# sensor
# iot
# internet-of-things
# c
# cpp
# java
# python
# nodejs
# upm
# kinect
# sdk
#
#
# react-native
# sensor
# gyroscope
# acceleration
# rxjs
# magnetometer
# barometer
#
#
# ios
# swift
# science
# education
#
# mpu6050
# catkin
# velodyne-sensor
# segmentation
# clustering
# velodyne
# real-time
# fast
# ros
# point-cloud
# depth-image
# depth
# range
# range-image
# pcl
# depth-clustering
# lidar
#
# python
# w1-therm-sensor
# temperature
# sensor
# beaglebone
# raspberrypi
# gpio
# hardware
# ds18b20
# ds18s20
# linux
# macchina
# sensor
# linux
# embedded-applications
# iot
# iot-framework
# javascript
# c-plus-plus
# edge
# edge-computing
# fog
# fog-computing
# device
# embedded-linux
# devices
# connected-device
# smart-products
# raspberry-pi
# grove-sensors
# grovepi
# grovepi-board
# iot
# iot-platform
# sensor
# arduino
# iot
# iot-device
# kinect
# 3d-reconstruction
# real-time
# multi-view-geometry
#
#
#
#
#
#
#
# home-assistant
# hue-sensors
# hue
# hue-lights
# raspberry-pi
# garage-door-opener
# monitor
# sensor
# appliance
#
# xiaomi
# xiaomi-smart-home
# miflora
# python3
# mqtt
# mqtt-connector
# openhab
# openhab2
# home-automation
# home-assistant
# homie
# mqtt-smarthome
# extended-kalman-filters
# lidar
# radar
# robotics-programming
# ros
# ros-moveit
# gazebo
# tutorial
# amazon
# sensor
# robot-framework
# robotframework
# robotics-book
# ros-book
# ros-navigation
# ros-industrial
# ros-indigo
# ros-kinetic
# diy
# multisensor
# sensornode
# homeassistant
# temperature
# humidity
# ota
# light
# enclosure
# photoresistor
# esp8266
# nodemcu
# wifi
# mqtt
# json
# led
# motion-detector
#
# iot
# arduino
# alarm
# telegram-bot
# node
# npm
# domotic
# raspberry-pi
# transmitter
# webhooks
# iot-433mhz
# radio-frequency
# nodejs
# nodemcu
# nodemcu-lua
# smartthings
#
#
#
# deeplearning
# video-combiner
# pytorch
# segmentation
# network
# 3d-object-detection
# sensor-fusion
# xamarin
# xamarin-plugin
# inertial-navigation-systems
# gnss
# gps
# imu
# integrated-navigation
#
#
# arduino
# arduino-ide
# lte
# cellular
# iot
# low-power
# microcontroller
# gps
# gnss
# nb-iot
#
#
#
#
# ios
# carthage
# cocoapods
# arduino
# sensor
# library
# fingerprint
# kicad
# soil-moisture
# avr
#
# daemon
# c
# linux
# webcam
# capture-frames
# screen-backlight
# gamma-correction
# brightness
# capture
# battery
# systemd
# html5
# sensor
# accelerometer
# gyroscope
#
# lidar
# lidar-camera-calibration
# lidar-data-manipulation
# lidar-measurements
# hdl
# velodyne-hdl-sensors
# velodyne
# velodyne-sensor
# sensor-streaming
# sensor-data
#
#
#
#
# stm32
# c
# sensors
# imu
#
#
#
# fuzzing
# pentesting
# scrapy
# crawler
# navigation
# inertial-sensors
# allan-variance
# imu
# gps
# gnu-octave
# integrated-navigation
# matlab-toolbox
# gnss
# sensors-simulation
# navego
# gnss-systems
# simulation-framework
# gnu-octave-toolbox
# home-assistant
# home-assistant-config
# hassio
# smart-home
# home-automation
# control-lights
# climate-control
# weather-report
# air-quality
# gtfs
# transit
# sensor
# raspberry-pi
# zwave
# homekit
# flic
# lifx
# limitlessled
# nanoleaf-aurora-lights
#
# robotics
# ros
# sensor-fusion
# robot-localization
# ekf-localization
# kalman-filter
# tutorial
#
# android-things
# google-cloud-pubsub
# temperature-sensor
# enclosure
# raspberry-pi
# gpio
# sensor
# filament-sensor
# temperature-alarm
# octoprint
# enclosure-plugin
# printer
# plugin
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# virtual-machine
# rubinius
# programming-languages
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# color
# color-picker
# figma
# figma-plugins
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# machine-learning
# deep-learning
# torch
# seq2seq
# neural-conversation-models
# machine-learning
# tutorial
# neural-network
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# home-automation
#
# alfred
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# clojure
# behaviour-tree
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# go
# dns
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cert-manager
# cert-manager-webhook
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# audio
# go
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# dice
# security
# cryptography
# encryption
# random
# password
# diceware
# passphrase
#
#
#
#
# api
# elixir
# phoenix
# otp
# rate-limits
# rate-limiting
# bucket
# rate
# rate-limit
#
#
#
#
#
# nist
# cryptography
# crypto
# random
# hash
# randomness
# timestamp
# beacon
#
#
#
# ruby
# rack
# security
# csp
# rubygems
# rack-middleware
# csp-directives
# signed-ruby-gems
# content-security-policy
# ruby
# rack
# middleware
# rubygems
# json
# jwt
# authentication
# dsl
# signature
# auth
# rack-middleware
# jwt-claims
# jwt-tokens
#
#
#
# cryptography
# crypto
# encryption
# signing
# signature
# key
# passphrase
# signing-keys
# encryption-key
# cryptographic
# keypair
# ed25519
# curve25519
# nacl
# digital-signature-keys
# digital-signature
# tweetnacl
# strength
# cryptography
# crypto
# encryption
# signing
# signing-keys
# encryption-key
# cryptographic
# keypair
# ed25519
# curve25519
# digital-signature
# tweetnacl
# strength
#
# ruby
# security
# rubygems
# cryptography
# crypto
# encryption
# authentication
# protocol
# signature
# remote
# verification
# password
# auth
# key
# srp
# srp-6a
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# javascript
# applescript
# illustrator
# adobe-illustrator
# extendscript
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# unmaintained
# actions
# tarballs
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# unmaintained
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# swift
#
#
#
#
#
#
# shell
# dotfiles
# bash
#
#
#
#
#
#
# docker
# trakt
# imdb
#
#
# javascript
# jquery
# c
# launchd
# dns
#
#
#
# sonos
# overcast
# smapi
# aws
# lambda
# xpdf
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# travis-ci
# circle-ci
# stoplight
# heroku-ci
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2769 entries, 0 to 2768
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   repo_name       2769 non-null   object
#  1   star            2769 non-null   int64
#  2   fork            2769 non-null   int64
#  3   watch           2769 non-null   int64
#  4   issue           2769 non-null   int64
#  5   tags            2769 non-null   object
#  6   description     2769 non-null   object
#  7   contributers    1500 non-null   float64
#  8   license         2769 non-null   int64
#  9   repo_url        2769 non-null   object
#  10  most_used_lang  2769 non-null   object
#  11  tag_ratio       2769 non-null   float64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 259.7+ KB

# %%
data.head()
# Out:
#                                            repo_name   star   fork  watch  \
# 0                                              keras  47900  18100   2100
# 1                                       scikit-learn  40300  19600   2200
# 2                          PythonDataScienceHandbook  23100   9900   1500
# 3  Probabilistic-Programming-and-Bayesian-Methods...  21000   6600   1400
# 4                          Data-Science--Cheat-Sheet  18400   8200   1500
#
#    issue                                               tags  \
# 0   2940  ['deep-learning', 'tensorflow', 'neural-networ...
# 1   1505  ['machine-learning', 'python', 'statistics', '...
# 2     65  ['scikit-learn', 'numpy', 'python', 'jupyter-n...
# 3    127  ['bayesian-methods', 'pymc', 'mathematical-ana...
# 4      7                                                 []
#
#                                          description  contributers  license  \
# 0                           Deep Learning for humans          49.0        1
# 1           scikit-learn: machine learning in Python         108.0        1
# 2  Python Data Science Handbook: full text in Jup...           0.0        1
# 3  aka "Bayesian Methods for Hackers": An introdu...           0.0        1
# 4                                       Cheat Sheets           0.0        0
#
#                                             repo_url    most_used_lang  \
# 0                https://github.com/keras-team/keras            Python
# 1       https://github.com/scikit-learn/scikit-learn            Python
# 2  https://github.com/jakevdp/PythonDataScienceHa...  Jupyter Notebook
# 3  https://github.com/CamDavidsonPilon/Probabilis...  Jupyter Notebook
# 4  https://github.com/abhat222/Data-Science--Chea...       no language
#
#    tag_ratio
# 0       9.31
# 1       5.97
# 2       2.42
# 3       1.72
# 4       0.00

# %% [markdown]
# Description is also play a role in the popularity of your repos, so we need to clean  `description` tuple by removing punctuations and creating word counts.

# %%
data['description']=data['description'].str.replace('\W'," ")
data['description']=data['description'].str.lower()

# %%
data['most_used_lang']=data['most_used_lang'].str.replace('\W'," ")
data['most_used_lang']=data['most_used_lang'].str.lower()

# %%
data['language']=data['most_used_lang'].str.split()
vocab = []
for words in data['language']:
    for word in words:
        vocab.append(word)
        
        
vocab = list(set(vocab))

# %%
data.head()
# Out:
#                                            repo_name   star   fork  watch  \
# 0                                              keras  47900  18100   2100
# 1                                       scikit-learn  40300  19600   2200
# 2                          PythonDataScienceHandbook  23100   9900   1500
# 3  Probabilistic-Programming-and-Bayesian-Methods...  21000   6600   1400
# 4                          Data-Science--Cheat-Sheet  18400   8200   1500
#
#    issue                                               tags  \
# 0   2940  ['deep-learning', 'tensorflow', 'neural-networ...
# 1   1505  ['machine-learning', 'python', 'statistics', '...
# 2     65  ['scikit-learn', 'numpy', 'python', 'jupyter-n...
# 3    127  ['bayesian-methods', 'pymc', 'mathematical-ana...
# 4      7                                                 []
#
#                                          description  contributers  license  \
# 0                           deep learning for humans          49.0        1
# 1           scikit learn  machine learning in python         108.0        1
# 2  python data science handbook  full text in jup...           0.0        1
# 3  aka  bayesian methods for hackers   an introdu...           0.0        1
# 4                                       cheat sheets           0.0        0
#
#                                             repo_url    most_used_lang  \
# 0                https://github.com/keras-team/keras            python
# 1       https://github.com/scikit-learn/scikit-learn            python
# 2  https://github.com/jakevdp/PythonDataScienceHa...  jupyter notebook
# 3  https://github.com/CamDavidsonPilon/Probabilis...  jupyter notebook
# 4  https://github.com/abhat222/Data-Science--Chea...       no language
#
#    tag_ratio             language
# 0       9.31             [python]
# 1       5.97             [python]
# 2       2.42  [jupyter, notebook]
# 3       1.72  [jupyter, notebook]
# 4       0.00       [no, language]

# %%
word_counts_for_language = {unique_word: [0] * len(data['language']) for unique_word in vocab}

for index, words in enumerate(data['language']):
    for word in words:
        word_counts_for_language[word][index] += 1

language_col=pd.DataFrame(word_counts_for_language)

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# Tokenizing the text data

# %%
text=[]
for index,row in data.iterrows():
    tokens=nltk.word_tokenize(row['description'])
    text.append(tokens)

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
stopword=stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /home/myth/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# To get numerical form of description , we create word dict according to their frequency i.e. the word which occurs more would be have low index value and removing words which has less `freq`(threshold=1)

# %%
def txt_to_num(text, threshold_rarewords = 1):
    
    # removing sublist from text list
    if len(text) > 1:
        text_list = [item for sublist in text for item in sublist]
    else:
        text_list = text
    
    # get word freuqncy
    freq_word = nltk.FreqDist(text_list)


    df = pd.DataFrame.from_dict(freq_word, orient='index')
    df.columns = ['freq']
      

    df.sort_values(by=['freq'], ascending=False, inplace=True)
  
    # Add word index
    number_of_words = df.shape[0]
    for word in df.index:
        if word in stopword:
            df.loc[word]['freq']=0
    df.sort_values('freq',inplace=True,ascending=False)
    
    df['word_index'] = list(np.arange(number_of_words)+1)
    
    # indexing 0 for rare words 
    frequency = df['freq'].values
    word_index = df['word_index'].values
    mask = frequency <= threshold_rarewords
    word_index[mask] = 0
    df['word_index'] =  word_index
    
    
    word_dict = df['word_index'].to_dict()
    # print(df.tail())
    # dict for word into num
    text_num = []
    for string in text:
        string_numbers = [word_dict[word] for word in string]
        text_num.append(string_numbers)  
    
    return (text_num, word_dict)

# %%
desc_num,word_dict=txt_to_num(text)
txt=[sum(x)  for x in desc_num]
data['desc_to_num']=txt

# %%
# repo_text=[]
# for index,row in data.iterrows():
#     tokens=nltk.word_tokenize(row['repo_name'])
#     repo_text.append(tokens)

# %%
# repo_num,repo_word_dict=txt_to_num(repo_text)
# txt=[sum(x)  for x in repo_num]
# data['repo_to_num']=txt

# %%
data.head()
# Out:
#                                            repo_name   star   fork  watch  \
# 0                                              keras  47900  18100   2100
# 1                                       scikit-learn  40300  19600   2200
# 2                          PythonDataScienceHandbook  23100   9900   1500
# 3  Probabilistic-Programming-and-Bayesian-Methods...  21000   6600   1400
# 4                          Data-Science--Cheat-Sheet  18400   8200   1500
#
#    issue                                               tags  \
# 0   2940  ['deep-learning', 'tensorflow', 'neural-networ...
# 1   1505  ['machine-learning', 'python', 'statistics', '...
# 2     65  ['scikit-learn', 'numpy', 'python', 'jupyter-n...
# 3    127  ['bayesian-methods', 'pymc', 'mathematical-ana...
# 4      7                                                 []
#
#                                          description  contributers  license  \
# 0                           deep learning for humans          49.0        1
# 1           scikit learn  machine learning in python         108.0        1
# 2  python data science handbook  full text in jup...           0.0        1
# 3  aka  bayesian methods for hackers   an introdu...           0.0        1
# 4                                       cheat sheets           0.0        0
#
#                                             repo_url    most_used_lang  \
# 0                https://github.com/keras-team/keras            python
# 1       https://github.com/scikit-learn/scikit-learn            python
# 2  https://github.com/jakevdp/PythonDataScienceHa...  jupyter notebook
# 3  https://github.com/CamDavidsonPilon/Probabilis...  jupyter notebook
# 4  https://github.com/abhat222/Data-Science--Chea...       no language
#
#    tag_ratio             language  desc_to_num
# 0       9.31             [python]          737
# 1       5.97             [python]          477
# 2       2.42  [jupyter, notebook]         1116
# 3       1.72  [jupyter, notebook]         9459
# 4       0.00       [no, language]         1439

# %% [markdown]
# From above we can see that their are some numerical values and stopwords too, so we need to remove them from vocabulary list

# %%
training_set = pd.concat([data, language_col],axis=1)
training_set.columns
# Out:
# Index(['repo_name', 'star', 'fork', 'watch', 'issue', 'tags', 'description',
#        'contributers', 'license', 'repo_url', 'most_used_lang', 'tag_ratio',
#        'language', 'desc_to_num', 'purebasic', 'emacs', 'jupyter', 'no',
#        'assembly', 'matlab', 'viml', 'kotlin', 'groff', 'groovy', 'vue',
#        'scala', 'erlang', 'lisp', 'java', 'typescript', 'actionscript',
#        'shaderlab', 'scheme', 'ruby', 'pascal', 'swift', 'javascript',
#        'coffeescript', 'jsonnet', 'clojure', 'r', 'apex', 'objective', 'dart',
#        'html', 'script', 'arc', 'rust', 'lua', 'qml', 'php', 'dockerfile',
#        'perl', 'notebook', 'vhdl', 'powershell', 'vim', 'tex', 'c', 'pure',
#        'makefile', 'eagle', 'julia', 'css', 'data', 'shell', 'ragel', 'elixir',
#        'ocaml', 'racket', 'processing', 'go', 'language', 'python', 'roff',
#        'xslt', 'freemarker', 'io', 'other', 'hcl', 'haskell'],
#       dtype='object')

# %%
training_set.drop(['repo_name', 'tags', 'description', 'repo_url', 'language', 'no', 'most_used_lang'], axis=1, inplace=True)

# %%
training_set = training_set.dropna()

# %% [markdown]
# ### Training model

# %%
## LR can be used:
# gradient descent
# random forest 
# NN regression (Relu)
# Lasso regression
# Ridge regression
# Elastic net regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
X_train, X_test, y_train, y_test = train_test_split(training_set.iloc[:,1:], training_set.iloc[:,0], test_size=0.2, random_state=22)

# %%
X_train.shape
# Out:
# (1200, 72)

# %%
ac=0

# %% [markdown]
# Gradient Descent

# %%
from sklearn.linear_model import SGDRegressor

sgd=SGDRegressor(loss='squared_loss',alpha=0.3,max_iter=5000)
sgd.fit(X_train, y_train)

predictions = sgd.predict(X_test)
mse = mean_squared_error(y_test, predictions, squared=False)

print('Mean Squared Error:', mse)
accu=r2_score(y_test, predictions)
print("R2 score: ", accu)

if accu > ac:
    model = sgd
    ac = accu
# Out:
# 3.303941592424989e+16
# R2 score:  -4.2170038614981604e+24

# %% [markdown]
# Normal Equation

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)

predictions = lr.predict(X_test)
mse = mean_squared_error(y_test, predictions, squared=False)

print("Mean Squared Error: ", mse)
accu=r2_score(y_test, predictions)
print("R2 score: ",accu)

if accu > ac:
    model = lr
    ac = accu
# Out:
# 5681.986682232555
# R2 score:  0.8752789669984791

# %% [markdown]
# Random forest

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(max_depth=8, random_state=25)
rf.fit(X_train, y_train)

predictions = rf.predict(X_test)
mse = mean_squared_error(y_test, predictions, squared=False)

print("Mean Squared Error: ", mse)
accu=r2_score(y_test, predictions)
print("R2 score: ",accu)

if accu > ac:
    model = rf
    ac = accu
# Out:
# 4801.792011241244
# R2 score:  0.9109270233630825

# %% [markdown]
# Lasso Regression

# %%
from sklearn import linear_model

las = linear_model.Lasso(alpha=0.3,max_iter=3000)
las.fit(X_train, y_train)

predictions = las.predict(X_test)
mse = mean_squared_error(y_test, predictions, squared=False)

print("Mean Squared Error: ", mse)
accu=r2_score(y_test, predictions)
print("R2 score: ",accu)

if accu > ac:
    model = las
    ac = accu
# Out:
# 5680.798186828632
# R2 score:  0.8753311370862266

# %% [markdown]
# Ridge Regression

# %%
from sklearn import linear_model

las = linear_model.Ridge(alpha=0.3,max_iter=3000)
las.fit(X_train, y_train)

predictions = las.predict(X_test)
mse = mean_squared_error(y_test, predictions, squared=False)

print("Mean Squared Error: ", mse)
accu=r2_score(y_test, predictions)
print("R2 score: ",accu)

if accu > ac:
    model = las
    ac = accu
# Out:
# 5689.720420421575
# R2 score:  0.874939220955455

# %% [markdown]
# Elastic Net Regression

# %%
from sklearn.linear_model import ElasticNet

elsnr = ElasticNet(alpha=0.03,max_iter=2000)
elsnr.fit(X_train, y_train)

predictions = elsnr.predict(X_test)
mse = mean_squared_error(y_test, predictions, squared=False)

print("Mean Squared Error: ", mse)
accu=r2_score(y_test, predictions)
print("R2 score: ",accu)

if accu > ac:
    model = elsnr
    ac = accu
# Out:
# 5848.999716530464
# R2 score:  0.8678392553627553

# %% [markdown]
# All results:
#
# | Methods                | MSE      | R2 Score |
# |------------------------|----------|----------|
# | Gradient Descent         | 3.303    | -4.217 |
# | Linear Regression        | 5681.986 | 0.875  |
# | Random Forest            | 4801.79  | 0.910  |
# | Lasso Regression         | 5680.798 | 0.8753 |
# | Ridge Regression         | 5689.72  | 0.8749 |
# | Elastic Net Regression   | 5848.99  | 0.868  |

# %% [markdown]
# In the above table, we can see that the `Random Forest` perform better than others methods with 0.91 r2 score.

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
from numpy import absolute

# %%
# xg = XGBRegressor(verbosity=1, eta=0.2)
# params = {'min_child_weight':[4,5], 'gamma':[i/10.0 for i in range(3,6)],  'subsample':[i/10.0 for i in range(6,11)],
# 'colsample_bytree':[i/10.0 for i in range(6,11)], 'max_depth': [4,6,7]}
# gb = GridSearchCV(xg,params)
# gb.fit(X_train, y_train)

# predictions = gb.predict(X_test)
# mse = mean_squared_error(y_test, predictions, squared=False)

# print("Mean Squared Error: ", mse)
# accu=r2_score(y_test, predictions)
# print("R2 score: ", accu)

# if accu > ac:
#     model = gb
#     ac = accu

# %%
# Saving the model in `pickle` format
with open('../pretrained_model/train_model.pkl', 'wb') as f:  
    pickle.dump(model, f)
with open('../pretrained_model/objs.pkl', 'wb') as f:  
    pickle.dump([store_tag, vocabulary, vocab, word_dict], f)

# %% [markdown]
# Testing the model on the repo to predict its popularity.

# %%
user_name=input("Enter username:")
repo_name=input("Enter repo name:")

# %%
header={'Accept':'application/vnd.github.mercy-preview+json',
'visibility':'PUBLIC',
"Authorization": "token PASTE_YOUR_GITHUB_TOKEN",
}

request=requests.get('https://api.github.com/repos/'+user_name+'/'+repo_name,headers=header)
data=request.json()
keys=['forks','watchers','open_issues_count','topics','description','language']

dataf=[data[k] for k in keys]
if str(data['license']).lower()=='none' or data['license']:
    license=0
else:
    license=1

request=requests.get('https://api.github.com/repos/'+user_name+'/'+repo_name+'contributors',headers=header)
dat=request.json()
contributors=len(dat)
dataf.append(contributors)
dataf.append(license)
df=pd.DataFrame([dataf],columns=['fork','watch','issue','tags','description','most_used_lang','contributers','license'])
def perc(tags):
    sum_of_perc=0
    for tag in tags:
        if tag in store_tag:
            sum_of_perc+=(store_tag[tag]/vocabulary)

    return (sum_of_perc*100)

df['tag_ratio']=df['tags'].apply(perc).astype(float)
text=nltk.word_tokenize(df['description'][0])
tex=nltk.word_tokenize(repo_name)

def string_num(text):
    string_numbers=0
    for string in text:
        if string in word_dict:
            string_numbers+=word_dict[string]
    return string_numbers

df['desc_to_num']=string_num(text)

word_counts_for_language = {unique_word: [0] for unique_word in vocab}

df['most_used_lang']=df['most_used_lang'].str.split()
for word in df['most_used_lang']:
    if word[0] in word_counts_for_language:
        word_counts_for_language[word[0].lower()][0] += 1

language_col=pd.DataFrame(word_counts_for_language)
test_set=pd.concat([df,language_col],axis=1)
test_set.drop(['tags','description','language','no','most_used_lang'], axis=1, inplace=True)

print("Your repo Popularity:",int(model.predict(test_set)[0]))
# Out:
# your repo Popularity: 35
